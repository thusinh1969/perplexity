# %%
from tavily import TavilyClient

client = TavilyClient("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")

response = client.search(

    query="Tóm tắt các thay đổi nổi bật của Python 3.13 và nguồn chính thức",

    search_depth="advanced"

)

print(response)

# %% [raw]
# !pip install tavily -U

# %%
response.keys()

# %%
response["follow_up_questions"]

# %%
response["answer"]

# %%
response["results"]

# %%
# Compress

# %%
prompt

# %%
from llmlingua import PromptCompressor

llm_lingua = PromptCompressor()

# %%
compressed_prompt = llm_lingua.compress_prompt(prompt, instruction="", question="", target_token=200)
compressed_prompt
# > {'compressed_prompt': 'Question: Sam bought a dozen boxes, each with 30 highlighter pens inside, for $10 each box. He reanged five of boxes into packages of sixlters each and sold them $3 per. He sold the rest theters separately at the of three pens $2. How much did make in total, dollars?\nLets think step step\nSam bought 1 boxes x00 oflters.\nHe bought 12 * 300ters in total\nSam then took 5 boxes 6ters0ters.\nHe sold these boxes for 5 *5\nAfterelling these  boxes there were 3030 highlighters remaining.\nThese form 330 / 3 = 110 groups of three pens.\nHe sold each of these groups for $2 each, so made 110 * 2 = $220 from them.\nIn total, then, he earned $220 + $15 = $235.\nSince his original cost was $120, he earned $235 - $120 = $115 in profit.\nThe answer is 115',
#  'origin_tokens': 2365,
#  'compressed_tokens': 211,
#  'ratio': '11.2x',
#  'saving': ', Saving $0.1 in GPT-4.'}

## Or use the quantation model, like TheBloke/Llama-2-7b-Chat-GPTQ, only need <8GB GPU memory.
## Before that, you need to pip install optimum auto-gptq
#ingua = PromptCompressor("TheBloke/Llama-2-7b-Chat-GPTQ", model_config={"revision": "main"})

# %%
from llmlingua import PromptCompressor

llm_lingua = PromptCompressor(
    model_name="microsoft/llmlingua-2-xlm-roberta-large-meetingbank",
    device_map="cpu",
    use_llmlingua2=True, # Whether to use llmlingua-2
)

# %%
compressed_prompt = llm_lingua.compress_prompt(prompt, rate=0.4, force_tokens = ['\n', '?'])

# %%
from llmlingua import PromptCompressor

## Or use LLMLingua-2-small model
llm_lingua = PromptCompressor(
    model_name="microsoft/llmlingua-2-bert-base-multilingual-cased-meetingbank",
    device_map="cpu",
    use_llmlingua2=True, # Whether to use llmlingua-2
)
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]

# %%
prompt="""Contributing
This project welcomes contributions and suggestions. Most contributions require you to agree to a Contributor License Agreement (CLA) declaring that you have the right to, and actually do, grant us the rights to use your contribution. For details, visit https://cla.opensource.microsoft.com.
When you submit a pull request, a CLA bot will automatically determine whether you need to provide a CLA and decorate the PR appropriately (e.g., status check, comment). Simply follow the instructions provided by the bot. You will only need to do this once across all repos using our CLA.
This project has adopted the Microsoft Open Source Code of Conduct. For more information see the Code of Conduct FAQ or contact opencode@microsoft.com with any additional questions or comments.
"""

# %%
compressed_prompt = llm_lingua.compress_prompt(prompt, rate=0.33, force_tokens = ['\n', '?'])
compressed_prompt
# Out:
# {'compressed_prompt': 'Contributing \n project welcomes contributions Contributor License Agreement rights contribution. visit https cla opensource microsoft com \n request CLA bot decorate PR status check comment follow instructions CLA. \n adopted Microsoft Open Source Code of Conduct opencode microsoft. com additional questions comments \n',
#  'compressed_prompt_list': ['Contributing \n project welcomes contributions Contributor License Agreement rights contribution. visit https cla opensource microsoft com \n request CLA bot decorate PR status check comment follow instructions CLA. \n adopted Microsoft Open Source Code of Conduct opencode microsoft. com additional questions comments \n'],
#  'origin_tokens': 152,
#  'compressed_tokens': 51,
#  'ratio': '3.0x',
#  'rate': '33.6%',
#  'saving': ', Saving $0.0 in GPT-4.'}

# %% [markdown]
# # Long compressions

# %%
from llmlingua import PromptCompressor

llm_lingua = PromptCompressor()
compressed_prompt = llm_lingua.compress_prompt(
    prompt_list,
    question=question,
    ratio=0.55,
    # Set the special parameter for LongLLMLingua
    condition_in_question="after_condition",
    reorder_context="sort",
    dynamic_context_compression_ratio=0.3, # or 0.4
    condition_compare=True,
    context_budget="+100",
    rank_method="longllmlingua",
)
